# %%
# Shiman, shiman@berkeley.edu

# %% [markdown]
# ## 6-1 Create table of Top Airports Information

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

pd.set_option('display.notebook_repr_html', False) # turn off html, i.e., without table.
pd.set_option('display.max_rows', 5)   # getting the summary of the view versus getting everything. Terminal takes time to buffer.

# %%
# read data
top_airport = pd.read_csv('Data/top_airports.csv')
airport_info = pd.read_csv('Data/ICAO_airports.csv')
print(top_airport)
# Out:
#             City  FAA IATA  ICAO  \
# 0        Atlanta  ATL  ATL  KATL
# 1        Chicago  ORD  ORD  KORD
# ..           ...  ...  ...   ...
# 48        Dallas  DAL  DAL  KDAL
# 49  Indianapolis  IND  IND  KIND
#
#                                              Airport Role  Enplanements
# 0   Hartsfield-Jackson Atlanta International Airport  P-L      43130585
# 1               Chicago O'Hare International Airport  P-L      32171831
# ..                                               ...  ...           ...
# 48                                 Dallas Love Field  P-M       3783407
# 49                Indianapolis International Airport  P-M       3728698
#
# [50 rows x 7 columns]

# %%
top_airport.columns
# Out:
# Index([u'City', u'FAA', u'IATA', u'ICAO', u'name', u'Role', u'Enplanements'], dtype='object')

# %%
airport_info.columns
# Out:
# Index([u'id', u'ICAO', u'type', u'name', u'latitude_deg', u'longitude_deg',
#        u'elevation_ft', u'continent', u'iso_country', u'iso_region',
#        u'municipality', u'scheduled_service', u'gps_code', u'iata_code',
#        u'local_code', u'home_link', u'wikipedia_link', u'keywords'],
#       dtype='object')

# %%
# rename column for consistency
top_airport.rename(columns={'Airport': 'name'}, inplace=True)
airport_info.rename(columns={'ident': 'ICAO'}, inplace=True)

# %%
top_airport_info = pd.merge(top_airport, airport_info, on=['ICAO'])

# %%
key_info = top_airport_info[['name_y', 'City', 'ICAO', 'latitude_deg', 'longitude_deg']]

# %%
key_info
# Out:
#                                               name_y          City  ICAO  \
# 0   Hartsfield Jackson Atlanta International Airport       Atlanta  KATL
# 1               Chicago O'Hare International Airport       Chicago  KORD
# ..                                               ...           ...   ...
# 48                                 Dallas Love Field        Dallas  KDAL
# 49                Indianapolis International Airport  Indianapolis  KIND
#
#     latitude_deg  longitude_deg
# 0      33.636700     -84.428101
# 1      41.978600     -87.904800
# ..           ...            ...
# 48     32.847099     -96.851799
# 49     39.717300     -86.294403
#
# [50 rows x 5 columns]

# %% [markdown]
# ## 6-2 Create table of Historical Weather Info

# %%
a = 'http://www.wunderground.com/history/airport/KSFO/2013/9/1/MonthlyHistory.html?format=1'
feature = ['PDT', 'Max TemperatureF', 'Min TemperatureF', ' Mean Humidity', 'PrecipitationIn', ' CloudCover']
aa = pd.read_csv(a)[feature]
aa.set_index('PDT')
# Out:
#            Max TemperatureF  Min TemperatureF   Mean Humidity PrecipitationIn  \
# PDT
# 2013-9-1                 74                58              68            0.00
# 2013-9-2                 75                62              77            0.00
# ...                     ...               ...             ...             ...
# 2013-9-29                75                57              70            0.00
# 2013-9-30                73                59              69               T
#
#             CloudCover
# PDT
# 2013-9-1             4
# 2013-9-2             6
# ...                ...
# 2013-9-29            3
# 2013-9-30            4
#
# [30 rows x 5 columns]

# %%
def readTemp(result, ICAO, date = '/2015/9/1/',
             feature = ['Max TemperatureF', 'Min TemperatureF', ' Mean Humidity', 'PrecipitationIn', ' CloudCover']):
    
    fname = 'http://www.wunderground.com/history/airport/' + ICAO + date + 'MonthlyHistory.html?format=1'
    ftemp = pd.read_csv(fname)[feature]
    idx = pd.date_range(date, periods=ftemp.size / len(feature) , freq='D')
    ftemp = ftemp.set_index(idx)
    result[ICAO] = ftemp
    return(result)

# %%
#Temp = pd.DataFrame()
#for k in key_info['ICAO']:
Temperature = dict()
for k in key_info['ICAO']:
    print(k)
    Temperature = readTemp(Temperature, k)
#frames = [readTemp(f) for f in key_info['ICAO']]
#Temperature = pd.concat(frames)
# Out:
# KATL
# KORD
# KLAX
# KDFW
# KDEN
# KJFK
# KSFO
# KIAH
# KLAS
# KPHX
# KCLT
# KMIA
# KMCO
# KEWR
# KDTW
# KMSP
# KSEA
# KPHL
# KBOS
# KLGA
# KIAD
# KBWI
# KFLL
# KSLC
# PHNL
# KDCA
# KMDW
# KSAN
# KTPA
# KPDX
# KSTL
# KMCI
# KMEM
# KCLE
# KOAK
# TJSJ
# KRDU
# KBNA
# KSMF
# KHOU
# KSNA
# KAUS
# KSJC
# KMSY
# KPIT
# KSAT
# KCVG
# KMKE
# KDAL
# KIND

# %%
Temperature
# Out:
# {'KATL':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                87                69              69
#  2015-09-02                90                73              67
#  ...                      ...               ...             ...
#  2015-09-29                77                70              88
#  2015-09-30                85                68              76
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            4
#  2015-09-02            0.00            5
#  ...                    ...          ...
#  2015-09-29            0.72            8
#  2015-09-30            0.00            5
#
#  [30 rows x 5 columns],
#  'KAUS':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                93                69              74
#  2015-09-02                93                65              71
#  ...                      ...               ...             ...
#  2015-09-29                93                65              67
#  2015-09-30                93                66              63
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.03            5
#  2015-09-02            0.00            4
#  ...                    ...          ...
#  2015-09-29            0.00            3
#  2015-09-30            0.00            1
#
#  [30 rows x 5 columns],
#  'KBNA':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                90                67              68
#  2015-09-02                93                70              64
#  ...                      ...               ...             ...
#  2015-09-29                78                69              81
#  2015-09-30                71                62              82
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            5
#  2015-09-02            0.00            6
#  ...                    ...          ...
#  2015-09-29            0.18            7
#  2015-09-30            0.03            8
#
#  [30 rows x 5 columns],
#  'KBOS':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                79                69              65
#  2015-09-02                91                66              63
#  ...                      ...               ...             ...
#  2015-09-29                84                65              79
#  2015-09-30                78                57              89
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            1
#  2015-09-02            0.00            0
#  ...                    ...          ...
#  2015-09-29            0.04            7
#  2015-09-30            2.46            8
#
#  [30 rows x 5 columns],
#  'KBWI':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                94                68              69
#  2015-09-02                92                69              69
#  ...                      ...               ...             ...
#  2015-09-29                79                68              88
#  2015-09-30                76                61              87
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            2
#  2015-09-02            0.00            6
#  ...                    ...          ...
#  2015-09-29            2.58            8
#  2015-09-30            0.12            8
#
#  [30 rows x 5 columns],
#  'KCLE':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                86                67              73
#  2015-09-02                89                68              70
#  ...                      ...               ...             ...
#  2015-09-29                75                60              88
#  2015-09-30                63                55              77
#
#             PrecipitationIn   CloudCover
#  2015-09-01               T            2
#  2015-09-02               T            4
#  ...                    ...          ...
#  2015-09-29            0.19            8
#  2015-09-30            0.02            7
#
#  [30 rows x 5 columns],
#  'KCLT':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                93                66              65
#  2015-09-02                94                69              64
#  ...                      ...               ...             ...
#  2015-09-29                80                73              84
#  2015-09-30                87                71              72
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            1
#  2015-09-02               T            4
#  ...                    ...          ...
#  2015-09-29            0.27            8
#  2015-09-30            0.28            7
#
#  [30 rows x 5 columns],
#  'KCVG':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                89                65              72
#  2015-09-02                90                65              74
#  ...                      ...               ...             ...
#  2015-09-29                72                66              95
#  2015-09-30                67                58              77
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            2
#  2015-09-02            0.00            1
#  ...                    ...          ...
#  2015-09-29            1.10            8
#  2015-09-30               T            8
#
#  [30 rows x 5 columns],
#  'KDAL':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                95                75              56
#  2015-09-02                95                73              55
#  ...                      ...               ...             ...
#  2015-09-29                91                72              57
#  2015-09-30                91                70              52
#
#              PrecipitationIn   CloudCover
#  2015-09-01                0            1
#  2015-09-02                0            1
#  ...                     ...          ...
#  2015-09-29                0            2
#  2015-09-30                0            1
#
#  [30 rows x 5 columns],
#  'KDCA':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                95                71              65
#  2015-09-02                94                75              68
#  ...                      ...               ...             ...
#  2015-09-29                80                71              87
#  2015-09-30                78                63              83
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            3
#  2015-09-02            0.00            7
#  ...                    ...          ...
#  2015-09-29            1.65            8
#  2015-09-30               T            8
#
#  [30 rows x 5 columns],
#  'KDEN':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                90                54              51
#  2015-09-02                92                63              33
#  ...                      ...               ...             ...
#  2015-09-29                78                54              69
#  2015-09-30                81                53              55
#
#             PrecipitationIn   CloudCover
#  2015-09-01               T            4
#  2015-09-02            0.00            5
#  ...                    ...          ...
#  2015-09-29            0.07            6
#  2015-09-30            0.00            6
#
#  [30 rows x 5 columns],
#  'KDFW':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                95                75              57
#  2015-09-02                95                73              59
#  ...                      ...               ...             ...
#  2015-09-29                92                71              55
#  2015-09-30                92                70              53
#
#              PrecipitationIn   CloudCover
#  2015-09-01                0            2
#  2015-09-02                0            1
#  ...                     ...          ...
#  2015-09-29                0            2
#  2015-09-30                0            1
#
#  [30 rows x 5 columns],
#  'KDTW':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                90                67              72
#  2015-09-02                91                70              72
#  ...                      ...               ...             ...
#  2015-09-29                74                57              83
#  2015-09-30                66                52              57
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            3
#  2015-09-02            0.00            3
#  ...                    ...          ...
#  2015-09-29            0.17            8
#  2015-09-30            0.00            6
#
#  [30 rows x 5 columns],
#  'KEWR':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                88                75              60
#  2015-09-02                91                71              72
#  ...                      ...               ...             ...
#  2015-09-29                82                71              81
#  2015-09-30                80                59              82
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            2
#  2015-09-02            0.00            3
#  ...                    ...          ...
#  2015-09-29            0.15            7
#  2015-09-30            1.16            8
#
#  [30 rows x 5 columns],
#  'KFLL':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                89                78              78
#  2015-09-02                89                80              81
#  ...                      ...               ...             ...
#  2015-09-29                89                78              80
#  2015-09-30                92                79              78
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.10            3
#  2015-09-02            0.10            5
#  ...                    ...          ...
#  2015-09-29            0.33            7
#  2015-09-30            0.00            4
#
#  [30 rows x 5 columns],
#  'KHOU':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                81                72              86
#  2015-09-02                89                73              78
#  ...                      ...               ...             ...
#  2015-09-29                90                69              75
#  2015-09-30                92                70              68
#
#             PrecipitationIn   CloudCover
#  2015-09-01               T            7
#  2015-09-02            0.02            5
#  ...                    ...          ...
#  2015-09-29               T            4
#  2015-09-30            0.00            1
#
#  [30 rows x 5 columns],
#  'KIAD':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                93                65              69
#  2015-09-02                93                69              67
#  ...                      ...               ...             ...
#  2015-09-29                79                69              87
#  2015-09-30                73                58              83
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            2
#  2015-09-02               T            5
#  ...                    ...          ...
#  2015-09-29            1.57            8
#  2015-09-30            0.04            8
#
#  [30 rows x 5 columns],
#  'KIAH':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                81                72              86
#  2015-09-02                89                73              85
#  ...                      ...               ...             ...
#  2015-09-29                90                69              77
#  2015-09-30                91                70              68
#
#              PrecipitationIn   CloudCover
#  2015-09-01             0.00            6
#  2015-09-02             0.02            5
#  ...                     ...          ...
#  2015-09-29             0.00            3
#  2015-09-30             0.00            1
#
#  [30 rows x 5 columns],
#  'KIND':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                86                70               0
#  2015-09-02                90                68              69
#  ...                      ...               ...             ...
#  2015-09-29                73                61              81
#  2015-09-30                69                56              61
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            4
#  2015-09-02            0.00            3
#  ...                    ...          ...
#  2015-09-29            0.27            8
#  2015-09-30               T            7
#
#  [30 rows x 5 columns],
#  'KJFK':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                87                73              66
#  2015-09-02                86                71              71
#  ...                      ...               ...             ...
#  2015-09-29                80                69              86
#  2015-09-30                78                60              80
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            2
#  2015-09-02            0.00            3
#  ...                    ...          ...
#  2015-09-29            0.13            7
#  2015-09-30            0.82            7
#
#  [30 rows x 5 columns],
#  'KLAS':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                99                81              22
#  2015-09-02               101                82              25
#  ...                      ...               ...             ...
#  2015-09-29               101                75              18
#  2015-09-30               101                75              16
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            1
#  2015-09-02            0.00            4
#  ...                    ...          ...
#  2015-09-29            0.00            3
#  2015-09-30            0.00            3
#
#  [30 rows x 5 columns],
#  'KLAX':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                78                68              68
#  2015-09-02                74                67              73
#  ...                      ...               ...             ...
#  2015-09-29                80                65              74
#  2015-09-30                82                67              71
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            6
#  2015-09-02            0.00            6
#  ...                    ...          ...
#  2015-09-29            0.00            1
#  2015-09-30            0.00            1
#
#  [30 rows x 5 columns],
#  'KLGA':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                88                76              55
#  2015-09-02                88                75              63
#  ...                      ...               ...             ...
#  2015-09-29                83                71              78
#  2015-09-30                78                59              80
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            1
#  2015-09-02            0.00            3
#  ...                    ...          ...
#  2015-09-29            0.08            7
#  2015-09-30            1.03            8
#
#  [30 rows x 5 columns],
#  'KMCI':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                91                72              67
#  2015-09-02                90                71              70
#  ...                      ...               ...             ...
#  2015-09-29                73                61              80
#  2015-09-30                70                48              65
#
#              PrecipitationIn   CloudCover
#  2015-09-01             0.00            2
#  2015-09-02             0.17            4
#  ...                     ...          ...
#  2015-09-29             0.00            7
#  2015-09-30             0.00            1
#
#  [30 rows x 5 columns],
#  'KMCO':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                92                75              78
#  2015-09-02                94                77              72
#  ...                      ...               ...             ...
#  2015-09-29                84                73              90
#  2015-09-30                91                75              76
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            5
#  2015-09-02               T            5
#  ...                    ...          ...
#  2015-09-29            0.44            8
#  2015-09-30            0.00            5
#
#  [30 rows x 5 columns],
#  'KMDW':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                89                74              69
#  2015-09-02                92                73              63
#  ...                      ...               ...             ...
#  2015-09-29                72                59              72
#  2015-09-30                63                55              54
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            1
#  2015-09-02            0.00            4
#  ...                    ...          ...
#  2015-09-29               T            7
#  2015-09-30            0.00            5
#
#  [30 rows x 5 columns],
#  'KMEM':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                94                73              61
#  2015-09-02                92                74              67
#  ...                      ...               ...             ...
#  2015-09-29                85                71              74
#  2015-09-30                77                67              72
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            6
#  2015-09-02            0.07            5
#  ...                    ...          ...
#  2015-09-29               T            6
#  2015-09-30               T            8
#
#  [30 rows x 5 columns],
#  'KMIA':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                91                80              76
#  2015-09-02                91                77              76
#  ...                      ...               ...             ...
#  2015-09-29                89                77              78
#  2015-09-30                92                78              74
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            3
#  2015-09-02            1.17            5
#  ...                    ...          ...
#  2015-09-29            0.50            8
#  2015-09-30               T            6
#
#  [30 rows x 5 columns],
#  'KMKE':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                90                66              72
#  2015-09-02                89                73              67
#  ...                      ...               ...             ...
#  2015-09-29                67                54              77
#  2015-09-30                59                52              62
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            2
#  2015-09-02               T            4
#  ...                    ...          ...
#  2015-09-29            0.63            7
#  2015-09-30            0.00            4
#
#  [30 rows x 5 columns],
#  'KMSP':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                86                69              76
#  2015-09-02                78                69              86
#  ...                      ...               ...             ...
#  2015-09-29                63                48              48
#  2015-09-30                63                43              51
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            6
#  2015-09-02            0.23            7
#  ...                    ...          ...
#  2015-09-29            0.00            2
#  2015-09-30            0.00            0
#
#  [30 rows x 5 columns],
#  'KMSY':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                91                75              64
#  2015-09-02                84                78              75
#  ...                      ...               ...             ...
#  2015-09-29                88                75              73
#  2015-09-30                89                75              64
#
#              PrecipitationIn   CloudCover
#  2015-09-01             0.00            6
#  2015-09-02             0.08            7
#  ...                     ...          ...
#  2015-09-29             0.00            5
#  2015-09-30             0.00            3
#
#  [30 rows x 5 columns],
#  'KOAK':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                75                58              67
#  2015-09-02                73                62              68
#  ...                      ...               ...             ...
#  2015-09-29                68                60              67
#  2015-09-30                65                57              80
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            2
#  2015-09-02            0.00            5
#  ...                    ...          ...
#  2015-09-29            0.00            7
#  2015-09-30               T            7
#
#  [30 rows x 5 columns],
#  'KORD':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                88                68              78
#  2015-09-02                90                72              69
#  ...                      ...               ...             ...
#  2015-09-29                68                55              83
#  2015-09-30                61                52              61
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            1
#  2015-09-02               T            3
#  ...                    ...          ...
#  2015-09-29            0.40            7
#  2015-09-30            0.00            4
#
#  [30 rows x 5 columns],
#  'KPDX':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                76                58              67
#  2015-09-02                73                58              68
#  ...                      ...               ...             ...
#  2015-09-29                81                48              61
#  2015-09-30                74                52              65
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.06            7
#  2015-09-02            0.05            6
#  ...                    ...          ...
#  2015-09-29            0.00            1
#  2015-09-30            0.00            2
#
#  [30 rows x 5 columns],
#  'KPHL':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                95                73              59
#  2015-09-02                93                73              63
#  ...                      ...               ...             ...
#  2015-09-29                85                68              79
#  2015-09-30                82                65              78
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            1
#  2015-09-02            0.00            4
#  ...                    ...          ...
#  2015-09-29            1.21            7
#  2015-09-30            0.27            8
#
#  [30 rows x 5 columns],
#  'KPHX':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                99                79              49
#  2015-09-02               101                84              38
#  ...                      ...               ...             ...
#  2015-09-29               103                79              29
#  2015-09-30               106                78              27
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            6
#  2015-09-02            0.00            6
#  ...                    ...          ...
#  2015-09-29            0.00            1
#  2015-09-30            0.00            2
#
#  [30 rows x 5 columns],
#  'KPIT':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                89                66              66
#  2015-09-02                90                70              64
#  ...                      ...               ...             ...
#  2015-09-29                70                64              91
#  2015-09-30                64                56              83
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            3
#  2015-09-02            0.00            5
#  ...                    ...          ...
#  2015-09-29            3.43            8
#  2015-09-30            0.07            8
#
#  [30 rows x 5 columns],
#  'KRDU':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                91                67              72
#  2015-09-02                94                68              72
#  ...                      ...               ...             ...
#  2015-09-29                82                74              93
#  2015-09-30                83                66              85
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            5
#  2015-09-02            0.10            4
#  ...                    ...          ...
#  2015-09-29            0.90            7
#  2015-09-30            0.06            7
#
#  [30 rows x 5 columns],
#  'KSAN':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                77                70              67
#  2015-09-02                76                69              64
#  ...                      ...               ...             ...
#  2015-09-29                80                69              71
#  2015-09-30                83                67              70
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            7
#  2015-09-02            0.00            6
#  ...                    ...          ...
#  2015-09-29            0.00            1
#  2015-09-30            0.00            3
#
#  [30 rows x 5 columns],
#  'KSAT':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                95                75              64
#  2015-09-02                94                73              62
#  ...                      ...               ...             ...
#  2015-09-29                94                67              60
#  2015-09-30                95                70              55
#
#             PrecipitationIn   CloudCover
#  2015-09-01               T            5
#  2015-09-02            0.00            4
#  ...                    ...          ...
#  2015-09-29            0.00            2
#  2015-09-30            0.00            1
#
#  [30 rows x 5 columns],
#  'KSEA':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                67                57              83
#  2015-09-02                67                52              71
#  ...                      ...               ...             ...
#  2015-09-29                71                48              69
#  2015-09-30                65                50              80
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.23            8
#  2015-09-02               T            5
#  ...                    ...          ...
#  2015-09-29            0.00            0
#  2015-09-30            0.00            4
#
#  [30 rows x 5 columns],
#  'KSFO':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                76                59              65
#  2015-09-02                73                62              68
#  ...                      ...               ...             ...
#  2015-09-29                67                57              69
#  2015-09-30                65                58              78
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            2
#  2015-09-02            0.00            5
#  ...                    ...          ...
#  2015-09-29            0.00            6
#  2015-09-30            0.02            6
#
#  [30 rows x 5 columns],
#  'KSJC':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                83                59              66
#  2015-09-02                78                57              68
#  ...                      ...               ...             ...
#  2015-09-29                71                57              70
#  2015-09-30                65                59              81
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            1
#  2015-09-02               T            2
#  ...                    ...          ...
#  2015-09-29               T            6
#  2015-09-30            0.01            6
#
#  [30 rows x 5 columns],
#  'KSLC':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                92                71              29
#  2015-09-02                92                74              24
#  ...                      ...               ...             ...
#  2015-09-29                84                62              45
#  2015-09-30                86                67              37
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            4
#  2015-09-02            0.00            4
#  ...                    ...          ...
#  2015-09-29            0.00            6
#  2015-09-30               T            6
#
#  [30 rows x 5 columns],
#  'KSMF':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                91                63              52
#  2015-09-02                84                60              61
#  ...                      ...               ...             ...
#  2015-09-29                80                57              53
#  2015-09-30                66                57              71
#
#              PrecipitationIn   CloudCover
#  2015-09-01             0.00            1
#  2015-09-02             0.00            1
#  ...                     ...          ...
#  2015-09-29             0.00            4
#  2015-09-30             0.01            7
#
#  [30 rows x 5 columns],
#  'KSNA':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                78                70              69
#  2015-09-02                77                69              68
#  ...                      ...               ...             ...
#  2015-09-29                81                64              66
#  2015-09-30                82                65              74
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            6
#  2015-09-02            0.00            5
#  ...                    ...          ...
#  2015-09-29            0.00            1
#  2015-09-30            0.00            1
#
#  [30 rows x 5 columns],
#  'KSTL':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                93                75              62
#  2015-09-02                94                75              58
#  ...                      ...               ...             ...
#  2015-09-29                79                63              75
#  2015-09-30                72                56              54
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            1
#  2015-09-02            0.00            3
#  ...                    ...          ...
#  2015-09-29            1.03            7
#  2015-09-30            0.00            4
#
#  [30 rows x 5 columns],
#  'KTPA':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                91                78              80
#  2015-09-02                91                79              71
#  ...                      ...               ...             ...
#  2015-09-29                89                76              82
#  2015-09-30                90                78              73
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.00            7
#  2015-09-02            0.00            5
#  ...                    ...          ...
#  2015-09-29            0.21            7
#  2015-09-30            0.00            2
#
#  [30 rows x 5 columns],
#  'PHNL':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                89                78              75
#  2015-09-02                87                76              83
#  ...                      ...               ...             ...
#  2015-09-29                87                78              65
#  2015-09-30                88                76              61
#
#             PrecipitationIn   CloudCover
#  2015-09-01            0.02            3
#  2015-09-02               T            4
#  ...                    ...          ...
#  2015-09-29               T            5
#  2015-09-30               T            4
#
#  [30 rows x 5 columns],
#  'TJSJ':             Max TemperatureF  Min TemperatureF   Mean Humidity  \
#  2015-09-01                90                77              78
#  2015-09-02                91                78              75
#  ...                      ...               ...             ...
#  2015-09-29                92                80              71
#  2015-09-30                92                79              64
#
#             PrecipitationIn   CloudCover
#  2015-09-01            1.65            4
#  2015-09-02            0.19            3
#  ...                    ...          ...
#  2015-09-29            0.00            3
#  2015-09-30            0.00            2
#
#  [30 rows x 5 columns]}

# %%
TempMonth = pd.Panel(Temperature)
TempMonth
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 50 (items) x 30 (major_axis) x 5 (minor_axis)
# Items axis: KATL to TJSJ
# Major_axis axis: 2015-09-01 00:00:00 to 2015-09-30 00:00:00
# Minor_axis axis: Max TemperatureF to  CloudCover

# %% [markdown]
# ## 6-3 Grab Historical Data from 2008

# %%
def MonthTemp(start_date = '/2015/9/1/'):
    Temperature = dict()
    for k in key_info['ICAO']:
        Temperature = readTemp(Temperature, k, date = start_date)
    print(start_date)
    return(pd.Panel(Temperature))

# %%
month_start = pd.date_range('2008/1/1', periods=100, freq='M')
hist_data = pd.Panel()
for d in range(len(month_start)):
    dt = "/" + pd.Series(month_start.format())[d].replace('-','/') + '/'
    hist_data = pd.concat([hist_data, MonthTemp(start_date = dt)], axis = 1)
# Out:
# /2008/01/31/
# /2008/02/29/
# /2008/03/31/
# /2008/04/30/
# /2008/05/31/
# /2008/06/30/
# /2008/07/31/
# /2008/08/31/
# /2008/09/30/
# /2008/10/31/
# /2008/11/30/
# /2008/12/31/
# /2009/01/31/
# /2009/02/28/
# /2009/03/31/
# /2009/04/30/
# /2009/05/31/
# /2009/06/30/
# /2009/07/31/
# /2009/08/31/
# /2009/09/30/
# /2009/10/31/
# /2009/11/30/
# /2009/12/31/
# /2010/01/31/
# /2010/02/28/
# /2010/03/31/
# /2010/04/30/
# /2010/05/31/
# /2010/06/30/
# /2010/07/31/
# /2010/08/31/
# /2010/09/30/
# /2010/10/31/
# /2010/11/30/
# /2010/12/31/
# /2011/01/31/
# /2011/02/28/
# /2011/03/31/
# /2011/04/30/
# /2011/05/31/
# /2011/06/30/
# /2011/07/31/
# /2011/08/31/
# /2011/09/30/
# /2011/10/31/
# /2011/11/30/
# /2011/12/31/
# /2012/01/31/
# /2012/02/29/
# /2012/03/31/
# /2012/04/30/
# /2012/05/31/
# /2012/06/30/
# /2012/07/31/
# /2012/08/31/
# /2012/09/30/
# /2012/10/31/
# /2012/11/30/
# /2012/12/31/
# /2013/01/31/
# /2013/02/28/
# /2013/03/31/
# /2013/04/30/
# /2013/05/31/
# /2013/06/30/
# /2013/07/31/
# /2013/08/31/
# /2013/09/30/
# /2013/10/31/
# /2013/11/30/
# /2013/12/31/
# /2014/01/31/
# /2014/02/28/
# /2014/03/31/
# /2014/04/30/
# /2014/05/31/
# /2014/06/30/
# /2014/07/31/
# /2014/08/31/
# /2014/09/30/
# /2014/10/31/
# /2014/11/30/
# /2014/12/31/
# /2015/01/31/
# /2015/02/28/
# /2015/03/31/
# /2015/04/30/
# /2015/05/31/
# /2015/06/30/
# /2015/07/31/
# /2015/08/31/
# /2015/09/30/
# /2015/10/31/
# /2015/11/30/
# /2015/12/31/
# /2016/01/31/
# /2016/02/29/
# /2016/03/31/
# /2016/04/30/

# %%
hist_data
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 50 (items) x 3043 (major_axis) x 5 (minor_axis)
# Items axis: KATL to TJSJ
# Major_axis axis: 2008-01-31 00:00:00 to 2016-05-29 00:00:00
# Minor_axis axis: Max TemperatureF to  CloudCover

# %%
pd.Series(month_start.format())[1].replace('-','/') + '/'
# Out:
# '2008/02/29/'
